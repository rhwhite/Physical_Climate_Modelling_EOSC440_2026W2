# %%
import intake
import xarray
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import intake
# ----> 2 import xarray
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import coders, groupers, testing, tutorial, ufuncs
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)
#      12     save_mfdataset,
#      13 )
#      14 from xarray.backends.zarr import open_zarr
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/coders.py:6
#       1 """
#       2 This module provides coder objects that encapsulate the
#       3 "encoding/decoding" process.
#       4 """
# ----> 6 from xarray.coding.times import CFDatetimeCoder, CFTimedeltaCoder
#       8 __all__ = ["CFDatetimeCoder", "CFTimedeltaCoder"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/coding/times.py:10
#       7 from functools import partial
#       8 from typing import TYPE_CHECKING, Union, cast
# ---> 10 import numpy as np
#      11 import pandas as pd
#      12 from pandas.errors import OutOfBoundsDatetime, OutOfBoundsTimedelta
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
import intake_esm
# url ="https://raw.githubusercontent.com/NCAR/intake-esm-datastore/main/catalogs/pangeo-cmip6.json"
url_official = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import intake_esm
#       2 # url ="https://raw.githubusercontent.com/NCAR/intake-esm-datastore/main/catalogs/pangeo-cmip6.json"
#       3 url_official = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/intake_esm/__init__.py:10
#       6 import intake
#       9 from intake_esm import tutorial
# ---> 10 from intake_esm.core import esm_datastore
#      11 from intake_esm.derived import DerivedVariableRegistry, default_registry
#      12 from intake_esm.utils import set_options, show_versions
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/intake_esm/core.py:9
#       7 import dask
#       8 import packaging.version
# ----> 9 import xarray as xr
#      11 try:
#      12     if packaging.version.Version(xr.__version__) < packaging.version.Version('2024.10'):
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import coders, groupers, testing, tutorial, ufuncs
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)
#      12     save_mfdataset,
#      13 )
#      14 from xarray.backends.zarr import open_zarr
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/coders.py:6
#       1 """
#       2 This module provides coder objects that encapsulate the
#       3 "encoding/decoding" process.
#       4 """
# ----> 6 from xarray.coding.times import CFDatetimeCoder, CFTimedeltaCoder
#       8 __all__ = ["CFDatetimeCoder", "CFTimedeltaCoder"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/coding/times.py:10
#       7 from functools import partial
#       8 from typing import TYPE_CHECKING, Union, cast
# ---> 10 import numpy as np
#      11 import pandas as pd
#      12 from pandas.errors import OutOfBoundsDatetime, OutOfBoundsTimedelta
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
cat = intake.open_esm_datastore(url_official)
cat.df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cat = intake.open_esm_datastore(url_official)
#       2 cat.df
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/intake/__init__.py:82, in __getattr__(attr)
#      80 if attr[:5] == "open_":
#      81     if attr[5:] in registry.drivers.enabled_plugins():
# ---> 82         driver = registry[attr[5:]]  # "open_..."
#      83         return driver
#      84     else:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/intake/source/__init__.py:30, in DriverRegistry.__getitem__(self, item)
#      28 it = self.drivers.enabled_plugins()[item]
#      29 if hasattr(it, "load"):
# ---> 30     return it.load()
#      31 if isinstance(it, str):
#      32     return import_name(it)
#
# File ~/miniconda3/envs/e440/lib/python3.12/importlib/metadata/__init__.py:205, in EntryPoint.load(self)
#     200 """Load the entry point from its definition. If only a module
#     201 is indicated by the value, return that module. Otherwise,
#     202 return the named object.
#     203 """
#     204 match = self.pattern.match(self.value)
# --> 205 module = import_module(match.group('module'))
#     206 attrs = filter(None, (match.group('attr') or '').split('.'))
#     207 return functools.reduce(getattr, attrs, module)
#
# File ~/miniconda3/envs/e440/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/intake_esm/__init__.py:10
#       6 import intake
#       9 from intake_esm import tutorial
# ---> 10 from intake_esm.core import esm_datastore
#      11 from intake_esm.derived import DerivedVariableRegistry, default_registry
#      12 from intake_esm.utils import set_options, show_versions
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/intake_esm/core.py:9
#       7 import dask
#       8 import packaging.version
# ----> 9 import xarray as xr
#      11 try:
#      12     if packaging.version.Version(xr.__version__) < packaging.version.Version('2024.10'):
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import coders, groupers, testing, tutorial, ufuncs
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)
#      12     save_mfdataset,
#      13 )
#      14 from xarray.backends.zarr import open_zarr
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/coders.py:6
#       1 """
#       2 This module provides coder objects that encapsulate the
#       3 "encoding/decoding" process.
#       4 """
# ----> 6 from xarray.coding.times import CFDatetimeCoder, CFTimedeltaCoder
#       8 __all__ = ["CFDatetimeCoder", "CFTimedeltaCoder"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/xarray/coding/times.py:10
#       7 from functools import partial
#       8 from typing import TYPE_CHECKING, Union, cast
# ---> 10 import numpy as np
#      11 import pandas as pd
#      12 from pandas.errors import OutOfBoundsDatetime, OutOfBoundsTimedelta
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
cat.df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cat.df
#
# NameError: name 'cat' is not defined

# %%
unique = cat.unique()
unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 unique = cat.unique()
#       2 unique
#
# NameError: name 'cat' is not defined

# %%
unique['source_id'].sort()
unique['source_id'][:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 unique['source_id'].sort()
#       2 unique['source_id'][:10]
#
# NameError: name 'unique' is not defined

# %%
experiments = unique['experiment_id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 experiments = unique['experiment_id']
#
# NameError: name 'unique' is not defined

# %%
experiments.sort()
experiments[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 experiments.sort()
#       2 experiments[:10]
#
# NameError: name 'experiments' is not defined

# %%
unique['table_id'][:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 unique['table_id'][:10]
#
# NameError: name 'unique' is not defined

# %%
cat_subset = cat.search(
    experiment_id=["historical","ssp585"],
    table_id=["Amon","fx"],
    source_id = ["CESM2","MIROC6"],
    variable_id=["clt","areacella"],
    grid_label="gn")
cat_subset.df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cat_subset = cat.search(
#       2     experiment_id=["historical","ssp585"],
#       3     table_id=["Amon","fx"],
#       4     source_id = ["CESM2","MIROC6"],
#       5     variable_id=["clt","areacella"],
#       6     grid_label="gn")
#       7 cat_subset.df.tail()
#
# NameError: name 'cat' is not defined

# %%
cat_subset.search(experiment_id = ["historical","ssp585"],source_id=["CESM2","MIROC6"]).df.sort_values("member_id").head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cat_subset.search(experiment_id = ["historical","ssp585"],source_id=["CESM2","MIROC6"]).df.sort_values("member_id").head()
#
# NameError: name 'cat_subset' is not defined

# %%
single_realization = cat_subset.search(experiment_id = ["historical","ssp585"],source_id=["CESM2","MIROC6"],member_id = "r10i1p1f1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 single_realization = cat_subset.search(experiment_id = ["historical","ssp585"],source_id=["CESM2","MIROC6"],member_id = "r10i1p1f1")
#
# NameError: name 'cat_subset' is not defined

# %%
single_realization.df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 single_realization.df
#
# NameError: name 'single_realization' is not defined

# %%
# get aeracella for miroc6 historical r10i1p1f1
ds = xarray.open_zarr(single_realization.df.iloc[0]['zstore'])
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # get aeracella for miroc6 historical r10i1p1f1
# ----> 2 ds = xarray.open_zarr(single_realization.df.iloc[0]['zstore'])
#       3 ds
#
# NameError: name 'xarray' is not defined

# %%
cat.esmcat.aggregation_control
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cat.esmcat.aggregation_control
#
# NameError: name 'cat' is not defined

# %%
dset_dict = single_realization.to_dataset_dict(
        xarray_open_kwargs={"consolidated": True, "decode_times": True, "use_cftime": True}
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dset_dict = single_realization.to_dataset_dict(
#       2         xarray_open_kwargs={"consolidated": True, "decode_times": True, "use_cftime": True}
#       3     )
#
# NameError: name 'single_realization' is not defined

# %%
dset_dict.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dset_dict.keys()
#
# NameError: name 'dset_dict' is not defined

# %%
fx_keys = [key for key in dset_dict.keys() if key.find('fx') > -1]
cl_keys = [key for key in dset_dict.keys() if key.find('Amon') > -1]
fx_keys.sort()
cl_keys.sort()
fx_keys, cl_keys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 fx_keys = [key for key in dset_dict.keys() if key.find('fx') > -1]
#       2 cl_keys = [key for key in dset_dict.keys() if key.find('Amon') > -1]
#       3 fx_keys.sort()
#
# NameError: name 'dset_dict' is not defined

# %%
def get_so(the_ds):
    """
    slice the dataset for latitudes south of -30 degrees
    """
    #
    # logical index of all latitudes south of -30
    #
    hit = the_ds.lat < -30
    so_slice = the_ds.isel(indexers = {'lat':hit})
    return so_slice

# %%
for key, ds in dset_dict.items():
    dset_dict[key]=get_so(ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 for key, ds in dset_dict.items():
#       2     dset_dict[key]=get_so(ds)
#
# NameError: name 'dset_dict' is not defined

# %%
ds = dset_dict['ScenarioMIP.NCAR.CESM2.ssp585.Amon.gn']
weights = dset_dict['ScenarioMIP.NCAR.CESM2.ssp585.fx.gn']['areacella']
print(f"{ds.experiment_id=}, {ds.member_id.data[0]=}, {ds.source_id=}")
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ds = dset_dict['ScenarioMIP.NCAR.CESM2.ssp585.Amon.gn']
#       2 weights = dset_dict['ScenarioMIP.NCAR.CESM2.ssp585.fx.gn']['areacella']
#       3 print(f"{ds.experiment_id=}, {ds.member_id.data[0]=}, {ds.source_id=}")
#
# NameError: name 'dset_dict' is not defined

# %%
weights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 weights
#
# NameError: name 'weights' is not defined

# %%
ds['clt'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ds['clt'].shape
#
# NameError: name 'ds' is not defined

# %%
ds = ds.squeeze()
weights = weights.squeeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 ds = ds.squeeze()
#       2 weights = weights.squeeze()
#
# NameError: name 'ds' is not defined

# %%
clt_so  = ds['clt']
clt_so =  ds['clt'].weighted(weights)
clt_so
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 clt_so  = ds['clt']
#       2 clt_so =  ds['clt'].weighted(weights)
#       3 clt_so
#
# NameError: name 'ds' is not defined

# %%
clt_so_zonal = clt_so.mean(dim=["lon","lat"])
clt_so_zonal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 clt_so_zonal = clt_so.mean(dim=["lon","lat"])
#       2 clt_so_zonal
#
# NameError: name 'clt_so' is not defined

# %%
from matplotlib import pyplot as plt
rolling = clt_so_zonal.rolling(time=60)
clt_mean = rolling.mean()
fig, ax = plt.subplots(1,1,figsize=(8,8))
clt_mean.plot(ax=ax,label = f"{ds.experiment_id}, {ds.source_id}")
ax.grid(True)
ax.set(title="southern ocean cloud fraction",
    xlabel="time (years)", ylabel = "cloud fraction (percent)")
fig.legend();
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from matplotlib import pyplot as plt
#       2 rolling = clt_so_zonal.rolling(time=60)
#       3 clt_mean = rolling.mean()
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/matplotlib/cbook.py:24
#      21 import types
#      22 import weakref
# ---> 24 import numpy as np
#      26 try:
#      27     from numpy.exceptions import VisibleDeprecationWarning  # numpy >= 1.25
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
def make_average(ds, weights):
    ds = ds.squeeze()
    weights = weights.squeeze()
    clt_so_weighted = ds['clt'].weighted(weights)
    clt_so_zonal = clt_so_weighted.mean(dim=["lon","lat"])
    rolling = clt_so_zonal.rolling(time=60)
    clt_mean = rolling.mean()
    return clt_mean

# %%
ds_miroc =dset_dict['ScenarioMIP.MIROC.MIROC6.ssp585.Amon.gn']
weights_miroc = dset_dict['ScenarioMIP.MIROC.MIROC6.ssp585.fx.gn']['areacella']
miroc6_clt_mean = make_average(ds_miroc, weights_miroc)
miroc6_clt_mean.plot(ax=ax,label = f"{ds.source_id}, {ds.source_id}")
ax.set(title = (f"Southern ocean cloud fraction comparison: "
                f"{ds.source_id}:{ds.experiment_id} vs "
                f"{ds_miroc.source_id}:{ds_miroc.experiment_id}"),
       xlabel = "time (year)", ylabel = "cloud faction (percent)")
fig.legend()
display(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 ds_miroc =dset_dict['ScenarioMIP.MIROC.MIROC6.ssp585.Amon.gn']
#       2 weights_miroc = dset_dict['ScenarioMIP.MIROC.MIROC6.ssp585.fx.gn']['areacella']
#       3 miroc6_clt_mean = make_average(ds_miroc, weights_miroc)
#
# NameError: name 'dset_dict' is not defined

# %%
dset_dict.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 dset_dict.keys()
#
# NameError: name 'dset_dict' is not defined

# %%
ds_miroc =dset_dict['CMIP.MIROC.MIROC6.historical.Amon.gn']
weights_miroc = dset_dict['CMIP.MIROC.MIROC6.historical.fx.gn']['areacella']
miroc6_clt_mean = make_average(ds_miroc, weights_miroc)
miroc6_clt_mean.plot(ax=ax,label = f"{ds.source_id}, {ds.source_id}")
ds_cesm =dset_dict['CMIP.NCAR.CESM2.historical.Amon.gn']
weights_cesm = dset_dict['CMIP.NCAR.CESM2.historical.fx.gn']['areacella']
cesm_clt_mean = make_average(ds_cesm, weights_cesm)
cesm_clt_mean.plot(ax=ax,label = f"{ds.source_id}, {ds.source_id}")
ax.set(title = (f"Southern ocean cloud fraction comparison: "
                f"{ds.source_id}:{ds.experiment_id} vs "
                f"{ds_miroc.source_id}:{ds_miroc.experiment_id}"),
       xlabel = "time (year)", ylabel = "cloud faction (percent)")
fig.legend()
display(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 ds_miroc =dset_dict['CMIP.MIROC.MIROC6.historical.Amon.gn']
#       2 weights_miroc = dset_dict['CMIP.MIROC.MIROC6.historical.fx.gn']['areacella']
#       3 miroc6_clt_mean = make_average(ds_miroc, weights_miroc)
#
# NameError: name 'dset_dict' is not defined
