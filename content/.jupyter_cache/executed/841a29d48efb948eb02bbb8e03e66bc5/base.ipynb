# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2482, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2480     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2481 with self.builtin_trap:
# -> 2482     result = fn(*args, **kwargs)
#    2484 # The code below prevents the output from being displayed
#    2485 # when using magics with decorator @output_can_be_silenced
#    2486 # when the last Python token in the expression is a ';'.
#    2487 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/IPython/core/magics/pylab.py:103, in PylabMagics.matplotlib(self, line)
#      98     print(
#      99         "Available matplotlib backends: %s"
#     100         % _list_matplotlib_backends_and_gui_loops()
#     101     )
#     102 else:
# --> 103     gui, backend = self.shell.enable_matplotlib(args.gui)
#     104     self._show_matplotlib_backend(args.gui, backend)
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3667, in InteractiveShell.enable_matplotlib(self, gui)
#    3664     import matplotlib_inline.backend_inline
#    3666 from IPython.core import pylabtools as pt
# -> 3667 gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3669 if gui != None:
#    3670     # If we have our first gui selection, store it
#    3671     if self.pylab_gui_select is None:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/IPython/core/pylabtools.py:338, in find_gui_and_backend(gui, gui_select)
#     321 def find_gui_and_backend(gui=None, gui_select=None):
#     322     """Given a gui string return the gui and mpl backend.
#     323
#     324     Parameters
#    (...)
#     335     'WXAgg','Qt4Agg','module://matplotlib_inline.backend_inline','agg').
#     336     """
# --> 338     import matplotlib
#     340     if _matplotlib_manages_backends():
#     341         backend_registry = matplotlib.backends.registry.backend_registry
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/matplotlib/cbook.py:24
#      21 import types
#      22 import weakref
# ---> 24 import numpy as np
#      26 try:
#      27     from numpy.exceptions import VisibleDeprecationWarning  # numpy >= 1.25
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
## The NOAA ESRL server is shutdown! January 2019
ncep_url = "http://www.esrl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/"
ncep_air = xr.open_dataset( ncep_url + "pressure/air.mon.1981-2010.ltm.nc",
                          use_cftime=True)
#url = 'http://apdrc.soest.hawaii.edu:80/dods/public_data/Reanalysis_Data/NCEP/NCEP/clima/pressure/air'
#air = xr.open_dataset(url)
## The name of the vertical axis is different than the NOAA ESRL version..
#ncep_air = air.rename({'lev': 'level'})
print( ncep_air)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 ## The NOAA ESRL server is shutdown! January 2019
#       2 ncep_url = "http://www.esrl.noaa.gov/psd/thredds/dodsC/Datasets/ncep.reanalysis.derived/"
# ----> 3 ncep_air = xr.open_dataset( ncep_url + "pressure/air.mon.1981-2010.ltm.nc",
#       4                           use_cftime=True)
#       5 #url = 'http://apdrc.soest.hawaii.edu:80/dods/public_data/Reanalysis_Data/NCEP/NCEP/clima/pressure/air'
#       6 #air = xr.open_dataset(url)
#       7 ## The name of the vertical axis is different than the NOAA ESRL version..
#       8 #ncep_air = air.rename({'lev': 'level'})
#       9 print( ncep_air)
#
# NameError: name 'xr' is not defined

# %%
#  Take global, annual average and convert to Kelvin
coslat = np.cos(np.deg2rad(ncep_air.lat))
weight = coslat / coslat.mean(dim='lat')
Tglobal = (ncep_air.air * weight).mean(dim=('lat','lon','time'))
Tglobal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #  Take global, annual average and convert to Kelvin
# ----> 2 coslat = np.cos(np.deg2rad(ncep_air.lat))
#       3 weight = coslat / coslat.mean(dim='lat')
#       4 Tglobal = (ncep_air.air * weight).mean(dim=('lat','lon','time'))
#
# NameError: name 'np' is not defined

# %%
#  a "quick and dirty" visualization of the data
Tglobal.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #  a "quick and dirty" visualization of the data
# ----> 2 Tglobal.plot()
#
# NameError: name 'Tglobal' is not defined

# %%
from metpy.plots import SkewT
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from metpy.plots import SkewT
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/metpy/__init__.py:13
#      10 warnings.filterwarnings('ignore', 'numpy.dtype size changed')
#      12 from ._version import get_version  # noqa: E402
# ---> 13 from .xarray import *  # noqa: F401, F403, E402
#      15 __version__ = get_version()
#      16 del get_version
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/metpy/xarray.py:25
#      22 import logging
#      23 import re
# ---> 25 import numpy as np
#      26 from pyproj import CRS, Proj
#      27 import xarray as xr
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
fig = plt.figure(figsize=(9, 9))
skew = SkewT(fig, rotation=30)
skew.plot(Tglobal.level, Tglobal, color='black', linestyle='-', linewidth=2, label='Observations')
skew.ax.set_ylim(1050, 10)
skew.ax.set_xlim(-75, 45)
# Add the relevant special lines
skew.plot_dry_adiabats(linewidth=0.5)
skew.plot_moist_adiabats(linewidth=0.5)
#skew.plot_mixing_lines()
skew.ax.legend()
skew.ax.set_title('Global, annual mean sounding from NCEP Reanalysis', 
             fontsize = 16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fig = plt.figure(figsize=(9, 9))
#       2 skew = SkewT(fig, rotation=30)
#       3 skew.plot(Tglobal.level, Tglobal, color='black', linestyle='-', linewidth=2, label='Observations')
#
# NameError: name 'plt' is not defined

# %%
#  Using pre-defined code for the Planck function from the climlab package
from climlab.utils.thermo import Planck_wavelength
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 #  Using pre-defined code for the Planck function from the climlab package
# ----> 2 from climlab.utils.thermo import Planck_wavelength
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/climlab/__init__.py:18
#      15     __version__ = get_distribution(__name__).version
#      17 # this should ensure that we can still import constants.py as climlab.constants
# ---> 18 from .utils import constants, thermo, legendre
#      19 # some more useful shorcuts
#      20 from .model.column import GreyRadiationModel, RadiativeConvectiveModel, BandRCModel
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/climlab/utils/constants.py:14
#       7 """Contains a collection of physical constants for the atmosphere and ocean.
#       8
#       9     .. literalinclude:: ../code_input_manual/constants.py
#      10
#      11 """
#      13 from __future__ import division
# ---> 14 from numpy import pi
#      16 a = 6.373E6      # Radius of Earth (m)
#      17 Lhvap = 2.5E6    # Latent heat of vaporization (J / kg)
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
# approximate emission temperature of the sun in Kelvin
Tsun = 5780.
# boundaries of visible region in nanometers
UVbound = 390.
IRbound = 700.
#  array of wavelengths
wavelength_nm = np.linspace(10., 3500., 400)
to_meters = 1E-9  # conversion factor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       5 IRbound = 700.
#       6 #  array of wavelengths
# ----> 7 wavelength_nm = np.linspace(10., 3500., 400)
#       8 to_meters = 1E-9  # conversion factor
#
# NameError: name 'np' is not defined

# %%
label_size = 16
fig, ax = plt.subplots(figsize=(14,7))
ax.plot(wavelength_nm, 
         Planck_wavelength(wavelength_nm * to_meters, Tsun))
ax.grid()
ax.set_xlabel('Wavelength (nm)', fontsize=label_size)
ax.set_ylabel('Spectral radiance (W sr$^{-1}$ m$^{-3}$)', fontsize=label_size)
#  Mask out points outside of this range
wavelength_vis = np.ma.masked_outside(wavelength_nm, UVbound, IRbound)
#  Shade the visible region
ax.fill_between(wavelength_vis, Planck_wavelength(wavelength_vis * to_meters, Tsun))
title = 'Blackbody emission curve for the sun (T = {:.0f} K)'.format(Tsun)
ax.set_title(title, fontsize=label_size);
ax.text(280, 0.8E13, 'Ultraviolet', rotation='vertical', fontsize=12)
ax.text(500, 0.8E13, 'Visible', rotation='vertical', fontsize=16, color='w')
ax.text(800, 0.8E13, 'Infrared', rotation='vertical', fontsize=12);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 label_size = 16
# ----> 2 fig, ax = plt.subplots(figsize=(14,7))
#       3 ax.plot(wavelength_nm,
#       4          Planck_wavelength(wavelength_nm * to_meters, Tsun))
#       5 ax.grid()
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots(figsize=(14,7))
wavelength_um = wavelength_nm / 1000
for T in [24000,12000,6000,3000]:
    ax.plot(wavelength_um, 
         (Planck_wavelength(wavelength_nm * to_meters, T) / T**4),
           label=str(T) + ' K')
ax.legend(fontsize=label_size)
ax.set_xlabel('Wavelength (um)', fontsize=label_size)
ax.set_ylabel('Normalized spectral radiance (W sr$^{-1}$ m$^{-3}$ K$^{-4}$)', fontsize=label_size)
ax.set_title("Normalized blackbody emission spectra $T^{-4} B_{\lambda}$ for different temperatures");
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# <>:10: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/y7/x8y_x12n4z5csyxs6xg_mvzc0000gp/T/ipykernel_21375/3204910202.py:10: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_title("Normalized blackbody emission spectra $T^{-4} B_{\lambda}$ for different temperatures");
# /var/folders/y7/x8y_x12n4z5csyxs6xg_mvzc0000gp/T/ipykernel_21375/3204910202.py:10: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_title("Normalized blackbody emission spectra $T^{-4} B_{\lambda}$ for different temperatures");
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(14,7))
#       2 wavelength_um = wavelength_nm / 1000
#       3 for T in [24000,12000,6000,3000]:
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots(figsize=(14,7))
wavelength_um = np.linspace(0.1, 200, 10000)
wavelength_meters = wavelength_um / 1E6

for T in [6000, 255]:
    ax.semilogx(wavelength_um, 
         (Planck_wavelength(wavelength_meters, T) / T**4 * wavelength_meters),
           label=str(T) + ' K')
ax.legend(fontsize=label_size)
ax.set_xlabel('Wavelength (um)', fontsize=label_size)
ax.set_ylabel('Normalized spectral radiance (W sr$^{-1}$ m$^{-2}$ K$^{-4}$)', fontsize=label_size)
ax.set_title("Normalized blackbody emission spectra $T^{-4} \lambda B_{\lambda}$ for the sun ($T_e = 6000$ K) and Earth ($T_e = 255$ K)",
            fontsize=label_size);
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# <>:12: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/y7/x8y_x12n4z5csyxs6xg_mvzc0000gp/T/ipykernel_21375/3044603190.py:12: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_title("Normalized blackbody emission spectra $T^{-4} \lambda B_{\lambda}$ for the sun ($T_e = 6000$ K) and Earth ($T_e = 255$ K)",
# /var/folders/y7/x8y_x12n4z5csyxs6xg_mvzc0000gp/T/ipykernel_21375/3044603190.py:12: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_title("Normalized blackbody emission spectra $T^{-4} \lambda B_{\lambda}$ for the sun ($T_e = 6000$ K) and Earth ($T_e = 255$ K)",
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(14,7))
#       2 wavelength_um = np.linspace(0.1, 200, 10000)
#       3 wavelength_meters = wavelength_um / 1E6
#
# NameError: name 'plt' is not defined
