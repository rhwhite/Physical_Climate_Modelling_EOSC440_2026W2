# %%
from datetime import timedelta

import numpy as np
import pandas as pd
import xarray as xr
from pythia_datasets import DATASETS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from datetime import timedelta
# ----> 3 import numpy as np
#       4 import pandas as pd
#       5 import xarray as xr
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
data = 283 + 5 * np.random.randn(5, 3, 4)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = 283 + 5 * np.random.randn(5, 3, 4)
#       2 data
#
# NameError: name 'np' is not defined

# %%
temp = xr.DataArray(data)
temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 temp = xr.DataArray(data)
#       2 temp
#
# NameError: name 'xr' is not defined

# %%
temp = xr.DataArray(data, dims=['time', 'lat', 'lon'])
temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 temp = xr.DataArray(data, dims=['time', 'lat', 'lon'])
#       2 temp
#
# NameError: name 'xr' is not defined

# %%
times = pd.date_range('2018-01-01', periods=5)
times
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 times = pd.date_range('2018-01-01', periods=5)
#       2 times
#
# NameError: name 'pd' is not defined

# %%
lons = np.linspace(-120, -60, 4)
lats = np.linspace(25, 55, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lons = np.linspace(-120, -60, 4)
#       2 lats = np.linspace(25, 55, 3)
#
# NameError: name 'np' is not defined

# %%
temp = xr.DataArray(data, coords=[times, lats, lons], dims=['time', 'lat', 'lon'])
temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 temp = xr.DataArray(data, coords=[times, lats, lons], dims=['time', 'lat', 'lon'])
#       2 temp
#
# NameError: name 'xr' is not defined

# %%
temp.attrs['units'] = 'kelvin'
temp.attrs['standard_name'] = 'air_temperature'

temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 temp.attrs['units'] = 'kelvin'
#       2 temp.attrs['standard_name'] = 'air_temperature'
#       4 temp
#
# NameError: name 'temp' is not defined

# %%
temp_in_celsius = temp - 273.15
temp_in_celsius
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 temp_in_celsius = temp - 273.15
#       2 temp_in_celsius
#
# NameError: name 'temp' is not defined

# %%
pressure_data = 1000.0 + 5 * np.random.randn(5, 3, 4)
pressure = xr.DataArray(
    pressure_data, coords=[times, lats, lons], dims=['time', 'lat', 'lon']
)
pressure.attrs['units'] = 'hPa'
pressure.attrs['standard_name'] = 'air_pressure'

pressure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pressure_data = 1000.0 + 5 * np.random.randn(5, 3, 4)
#       2 pressure = xr.DataArray(
#       3     pressure_data, coords=[times, lats, lons], dims=['time', 'lat', 'lon']
#       4 )
#       5 pressure.attrs['units'] = 'hPa'
#
# NameError: name 'np' is not defined

# %%
ds = xr.Dataset(data_vars={'Temperature': temp, 'Pressure': pressure})
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ds = xr.Dataset(data_vars={'Temperature': temp, 'Pressure': pressure})
#       2 ds
#
# NameError: name 'xr' is not defined

# %%
ds.Pressure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ds.Pressure
#
# NameError: name 'ds' is not defined

# %%
ds['Pressure']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ds['Pressure']
#
# NameError: name 'ds' is not defined

# %%
indexed_selection = temp[1, :, :]  # Index 1 along axis 0 is the time slice we want...
indexed_selection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 indexed_selection = temp[1, :, :]  # Index 1 along axis 0 is the time slice we want...
#       2 indexed_selection
#
# NameError: name 'temp' is not defined

# %%
named_selection = temp.sel(time='2018-01-02')
named_selection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 named_selection = temp.sel(time='2018-01-02')
#       2 named_selection
#
# NameError: name 'temp' is not defined

# %%
temp.sel(time='2018-01-07', method='nearest', tolerance=timedelta(days=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 temp.sel(time='2018-01-07', method='nearest', tolerance=timedelta(days=2))
#
# NameError: name 'temp' is not defined

# %%
temp.interp(lon=-105, lat=40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 temp.interp(lon=-105, lat=40)
#
# NameError: name 'temp' is not defined

# %%
temp.sel(
    time=slice('2018-01-01', '2018-01-03'), lon=slice(-110, -70), lat=slice(25, 45)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 temp.sel(
#       2     time=slice('2018-01-01', '2018-01-03'), lon=slice(-110, -70), lat=slice(25, 45)
#       3 )
#
# NameError: name 'temp' is not defined

# %%
temp.loc['2018-01-02']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 temp.loc['2018-01-02']
#
# NameError: name 'temp' is not defined

# %%
temp.loc['2018-01-01':'2018-01-03', 25:45, -110:-70]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 temp.loc['2018-01-01':'2018-01-03', 25:45, -110:-70]
#
# NameError: name 'temp' is not defined

# %%
temp.loc['2018-01-01':'2018-01-03', slice(25, 45), -110:-70]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 temp.loc['2018-01-01':'2018-01-03', slice(25, 45), -110:-70]
#
# NameError: name 'temp' is not defined

# %%
# This will generate an error
# temp.loc[-110:-70, 25:45,'2018-01-01':'2018-01-03']

# %%
filepath = DATASETS.fetch('NARR_19930313_0000.nc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 filepath = DATASETS.fetch('NARR_19930313_0000.nc')
#
# NameError: name 'DATASETS' is not defined

# %%
ds = xr.open_dataset(filepath)
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 ds = xr.open_dataset(filepath)
#       2 ds
#
# NameError: name 'xr' is not defined

# %%
ds.isobaric1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 ds.isobaric1
#
# NameError: name 'ds' is not defined

# %%
ds_1000 = ds.sel(isobaric1=1000.0)
ds_1000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 ds_1000 = ds.sel(isobaric1=1000.0)
#       2 ds_1000
#
# NameError: name 'ds' is not defined

# %%
ds_1000.Temperature_isobaric
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 ds_1000.Temperature_isobaric
#
# NameError: name 'ds_1000' is not defined

# %%
u_winds = ds['u-component_of_wind_isobaric']
u_winds.std(dim=['x', 'y'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 u_winds = ds['u-component_of_wind_isobaric']
#       2 u_winds.std(dim=['x', 'y'])
#
# NameError: name 'ds' is not defined

# %%
temps = ds.Temperature_isobaric
co_temps = temps.sel(x=slice(-182, 424), y=slice(-1450, -990))
prof = co_temps.mean(dim=['x', 'y'])
prof
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 temps = ds.Temperature_isobaric
#       2 co_temps = temps.sel(x=slice(-182, 424), y=slice(-1450, -990))
#       3 prof = co_temps.mean(dim=['x', 'y'])
#
# NameError: name 'ds' is not defined

# %%
prof.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 prof.plot()
#
# NameError: name 'prof' is not defined

# %%
prof.plot(y="isobaric1", yincrease=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 prof.plot(y="isobaric1", yincrease=False)
#
# NameError: name 'prof' is not defined

# %%
temps.sel(isobaric1=1000).plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 temps.sel(isobaric1=1000).plot()
#
# NameError: name 'temps' is not defined
