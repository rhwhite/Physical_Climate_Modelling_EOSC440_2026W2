# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from pythia_datasets import DATASETS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/overrides.py:8
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show as show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.12 from "/Users/rwhite/miniconda3/envs/e440/bin/python"
#   * The NumPy version is: "2.1.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/_multiarray_umath.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/rwhite/miniconda3/envs/e440/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/rwhite/miniconda3/envs/e440/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 import xarray as xr
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/matplotlib/cbook.py:24
#      21 import types
#      22 import weakref
# ---> 24 import numpy as np
#      26 try:
#      27     from numpy.exceptions import VisibleDeprecationWarning  # numpy >= 1.25
#
# File ~/miniconda3/envs/e440/lib/python3.12/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_, _get_promotion_state, _no_nep50_warning,
#     124     _set_promotion_state, abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.

# %%
filepath = DATASETS.fetch('CESM2_sst_data.nc')
ds = xr.open_dataset(filepath)
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 filepath = DATASETS.fetch('CESM2_sst_data.nc')
#       2 ds = xr.open_dataset(filepath)
#       3 ds
#
# NameError: name 'DATASETS' is not defined

# %%
ds.tos + 273.15
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds.tos + 273.15
#
# NameError: name 'ds' is not defined

# %%
ds.tos**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ds.tos**2
#
# NameError: name 'ds' is not defined

# %%
ds.tos.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds.tos.mean()
#
# NameError: name 'ds' is not defined

# %%
ds.tos.mean(dim='time').plot(size=7);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds.tos.mean(dim='time').plot(size=7);
#
# NameError: name 'ds' is not defined

# %%
ds.tos.min(dim=['time'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ds.tos.min(dim=['time'])
#
# NameError: name 'ds' is not defined

# %%
ds.tos.sum(dim=['lat', 'lon'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ds.tos.sum(dim=['lat', 'lon'])
#
# NameError: name 'ds' is not defined

# %%
ds.tos.median(dim='time')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ds.tos.median(dim='time')
#
# NameError: name 'ds' is not defined

# %%
ds.tos.sel(lon=310, lat=50, method='nearest').plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ds.tos.sel(lon=310, lat=50, method='nearest').plot();
#
# NameError: name 'ds' is not defined

# %%
ds.tos.groupby(ds.time.dt.month)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ds.tos.groupby(ds.time.dt.month)
#
# NameError: name 'ds' is not defined

# %%
ds.tos.groupby('time.month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ds.tos.groupby('time.month')
#
# NameError: name 'ds' is not defined

# %%
tos_clim = ds.tos.groupby('time.month').mean()
tos_clim
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tos_clim = ds.tos.groupby('time.month').mean()
#       2 tos_clim
#
# NameError: name 'ds' is not defined

# %%
tos_clim.sel(lon=310, lat=50, method='nearest').plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tos_clim.sel(lon=310, lat=50, method='nearest').plot();
#
# NameError: name 'tos_clim' is not defined

# %%
tos_clim.mean(dim='lon').transpose().plot.contourf(levels=12, cmap='turbo');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tos_clim.mean(dim='lon').transpose().plot.contourf(levels=12, cmap='turbo');
#
# NameError: name 'tos_clim' is not defined

# %%
(tos_clim.sel(month=1) - tos_clim.sel(month=12)).plot(size=6, robust=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 (tos_clim.sel(month=1) - tos_clim.sel(month=12)).plot(size=6, robust=True);
#
# NameError: name 'tos_clim' is not defined

# %%
gb = ds.tos.groupby('time.month')
tos_anom = gb - gb.mean(dim='time')
tos_anom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 gb = ds.tos.groupby('time.month')
#       2 tos_anom = gb - gb.mean(dim='time')
#       3 tos_anom
#
# NameError: name 'ds' is not defined

# %%
tos_anom.sel(lon=310, lat=50, method='nearest').plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tos_anom.sel(lon=310, lat=50, method='nearest').plot();
#
# NameError: name 'tos_anom' is not defined

# %%
unweighted_mean_global_anom = tos_anom.mean(dim=['lat', 'lon'])
unweighted_mean_global_anom.plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 unweighted_mean_global_anom = tos_anom.mean(dim=['lat', 'lon'])
#       2 unweighted_mean_global_anom.plot();
#
# NameError: name 'tos_anom' is not defined

# %%
filepath2 = DATASETS.fetch('CESM2_grid_variables.nc')
areacello = xr.open_dataset(filepath2).areacello
areacello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 filepath2 = DATASETS.fetch('CESM2_grid_variables.nc')
#       2 areacello = xr.open_dataset(filepath2).areacello
#       3 areacello
#
# NameError: name 'DATASETS' is not defined

# %%
weighted_mean_global_anom = tos_anom.weighted(areacello).mean(dim=['lat', 'lon'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 weighted_mean_global_anom = tos_anom.weighted(areacello).mean(dim=['lat', 'lon'])
#
# NameError: name 'tos_anom' is not defined

# %%
unweighted_mean_global_anom.plot(size=7)
weighted_mean_global_anom.plot()
plt.legend(['unweighted', 'weighted']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 unweighted_mean_global_anom.plot(size=7)
#       2 weighted_mean_global_anom.plot()
#       3 plt.legend(['unweighted', 'weighted']);
#
# NameError: name 'unweighted_mean_global_anom' is not defined

# %%
r = ds.tos.resample(time='AS')
r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 r = ds.tos.resample(time='AS')
#       2 r
#
# NameError: name 'ds' is not defined

# %%
r.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 r.mean()
#
# NameError: name 'r' is not defined

# %%
m_avg = ds.tos.rolling(time=5, center=True).mean()
m_avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 m_avg = ds.tos.rolling(time=5, center=True).mean()
#       2 m_avg
#
# NameError: name 'ds' is not defined

# %%
lat = 50
lon = 310

m_avg.isel(lat=lat, lon=lon).plot(size=6)
ds.tos.isel(lat=lat, lon=lon).plot()
plt.legend(['5-month moving average', 'monthly data']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       1 lat = 50
#       2 lon = 310
# ----> 4 m_avg.isel(lat=lat, lon=lon).plot(size=6)
#       5 ds.tos.isel(lat=lat, lon=lon).plot()
#       6 plt.legend(['5-month moving average', 'monthly data']);
#
# NameError: name 'm_avg' is not defined

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
sample = ds.tos.isel(time=-1)
sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sample = ds.tos.isel(time=-1)
#       2 sample
#
# NameError: name 'ds' is not defined

# %%
masked_sample = sample.where(sample < 0.0)
masked_sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 masked_sample = sample.where(sample < 0.0)
#       2 masked_sample
#
# NameError: name 'sample' is not defined

# %%
fig, axes = plt.subplots(ncols=2, figsize=(19, 6))
sample.plot(ax=axes[0])
masked_sample.plot(ax=axes[1]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fig, axes = plt.subplots(ncols=2, figsize=(19, 6))
#       2 sample.plot(ax=axes[0])
#       3 masked_sample.plot(ax=axes[1]);
#
# NameError: name 'plt' is not defined

# %%
sample.where((sample > 25) & (sample < 30)).plot(size=6);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sample.where((sample > 25) & (sample < 30)).plot(size=6);
#
# NameError: name 'sample' is not defined

# %%
sample.where(
    (sample.lat < 5) & (sample.lat > -5) & (sample.lon > 190) & (sample.lon < 240)
).plot(size=6);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sample.where(
#       2     (sample.lat < 5) & (sample.lat > -5) & (sample.lon > 190) & (sample.lon < 240)
#       3 ).plot(size=6);
#
# NameError: name 'sample' is not defined

# %%
sample.where((sample > 25) & (sample < 30), 0).plot(size=6);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sample.where((sample > 25) & (sample < 30), 0).plot(size=6);
#
# NameError: name 'sample' is not defined
